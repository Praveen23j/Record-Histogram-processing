# %% [markdown]
# ## EX No:03
# ### Histogram of an Images
# **Name:** Praveen J **Reg no:** 212224230205 **Slot:** T1-H15

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('WhatsApp Image 2025-08-08 at 08.58.49_6b30571d.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img,cmap='gray')
plt.title('Orginal Image')
plt.show()

# %%
plt.hist(img.ravel(),256,range = [0,256]);
plt.title('Orginal Image')
plt.show()

# %%
img_eq = cv2.equalizeHist(img)

# %%
plt.hist(img_eq.ravel(),256,range=[0,256]);
plt.title('Equalized HIstogram')
# Out:
# Text(0.5, 1.0, 'Equalized HIstogram')

# %%
plt.imshow(img_eq,cmap='gray')
plt.title('Orginal Image')
plt.show()

# %%
img = cv2.imread('WhatsApp Image 2025-08-08 at 08.58.49_6b30571d.jpg',cv2.IMREAD_COLOR)
img_hsv= cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
img_hsv[:,:,2]=cv2.equalizeHist(img_hsv[:,:,2])

# %%
img_eq=cv2.cvtColor(img_hsv,cv2.COLOR_HSV2BGR)
plt.imshow(img_eq[:,:,::-1]);
plt.title('Equalized Image')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(img_eq.ravel(),256,range=[0,256]);
plt.title('Equalized HIstogram')
# Out:
# Text(0.5, 1.0, 'Equalized HIstogram')

# %%
plt.hist(img_eq.ravel(),256,range = [0,256]);
plt.title('color image')
plt.show()
